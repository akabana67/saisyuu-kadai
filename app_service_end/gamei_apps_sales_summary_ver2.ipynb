# %% [markdown]
# ### 必要なライブラリのインポート

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ### アプリIDをWebページから抽出

# %%
headers = {
    "User-Agent": "Mozilla/5.0"
}

base_url = "https://game-i.daa.jp/?アプリサービス終了分析"
app_ids = set()

# 1ページ目（例外）
print(f"取得中: {base_url}")
res = requests.get(base_url, headers=headers, timeout=10)
ids = re.findall(r'2F(\d{10})', res.text)
app_ids.update(ids)
time.sleep(1)

# 2ページ目以降（6か月ずつ遡る）
current = datetime.strptime("2025-02", "%Y-%m")
limit = datetime.strptime("2018-01", "%Y-%m")

while current >= limit:
    ym_str = current.strftime("%Y-%m")
    url = f"https://game-i.daa.jp/?アプリサービス終了分析&Ym={ym_str}"
    print(f"取得中: {url}")
    try:
        res = requests.get(url, headers=headers, timeout=10)
        res.raise_for_status()
    except Exception as e:
        print(f"エラー: {e}")
        break

    found_ids = re.findall(r'2F(\d{10})', res.text)
    if not found_ids:
        print(f"IDなし: {ym_str}")
        break

    app_ids.update(found_ids)
    time.sleep(1)
    current -= relativedelta(months=6)

# 結果出力
app_ids = sorted(list(app_ids))
print(f"\n 抽出完了: {len(app_ids)} 件")
# Out:
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2025-02
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2024-08
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2024-02
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2023-08
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2023-02
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2022-08
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2022-02
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2021-08
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2021-02
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2020-08
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2020-02
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2019-08
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2019-02
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2018-08
# 取得中: https://game-i.daa.jp/?アプリサービス終了分析&Ym=2018-02
# IDなし: 2018-02
#
#  抽出完了: 393 件

# %% [markdown]
# ### CSVに保存

# %%
pd.DataFrame({"app_id": app_ids}).to_csv("extracted_app_ids.csv", index=False)

# %% [markdown]
# ### アプリ情報を抽出

# %%
app_ids_df = pd.read_csv("extracted_app_ids.csv")
app_ids = app_ids_df['app_id'].astype(str).tolist()

headers = {
    "User-Agent": "Mozilla/5.0"
}

results = []

for app_id in app_ids:
    url = f"https://game-i.daa.jp/?APP%2F{app_id}"
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
    except Exception as e:
        print(f"エラー: {app_id} - {e}")
        continue

    soup = BeautifulSoup(response.text, "html.parser")

    # タイトル抽出（「アプリ/」と「【売上＆人気アプリランキング】」を除去）
    title_tag = soup.find("title")
    if not title_tag:
        print(f"スキップ（タイトルなし）: {app_id}")
        continue

    title_raw = title_tag.text.strip()
    match = re.search(r"アプリ/(.+?)【売上＆人気アプリランキング】", title_raw)
    if match:
        title = match.group(1).strip()
    else:
        print(f"スキップ（形式外タイトル）: {app_id}")
        continue

    # 関連ジャンル
    genre_tag = soup.find("td", string=re.compile("関連ジャンル"))
    genre = genre_tag.find_next_sibling("td").text.strip().replace("\n", " ").replace(",", " ") if genre_tag else ""

    # サービス終了日（<strong>タグ内にある場合に対応）
    end_service = ""
    for td in soup.find_all("td", class_="style_td"):
        if "サービス終了" in td.get_text():
            strong = td.find("strong")
            if strong:
                end_service = strong.get_text(strip=True)
                break

    # 年月と売上予測（2018〜2025）
    for year in range(2018, 2026):
        panel = soup.find("div", id=f"panel{year}")
        if not panel:
            continue
        rows = panel.find_all("tr", class_="customtbl")
        for row in rows[1:]:
            cols = row.find_all("td")
            if len(cols) < 2:
                continue
            ym_tag = cols[0].find("a") or cols[0].find("span")
            sales_tag = cols[1].find("span")
            if not ym_tag or not sales_tag:
                continue
            ym = ym_tag.text.strip()
            sales = sales_tag.text.strip()
            if not re.match(r"^\d{4}/\d{2}$", ym):
                continue
            if sales in ["-", "未", ""]:
                continue
            results.append({
                "タイトル": title,
                "年月": f'="{ym}"',
                "売上予測": sales,
                "関連ジャンル": genre,
                "サービス終了日": end_service
            })

    print(f"抽出完了: {title}")
    time.sleep(1)  # アクセス間隔
# Out:
# 抽出完了: スーパーガンダムロワイヤル
# 抽出完了: 武器よさらば
# 抽出完了: スーパーロボット大戦X-Ω
# 抽出完了: FINAL FANTASY GRANDMASTERS
# 抽出完了: ドラゴンプロジェクト
# 抽出完了: 戦の海賊
# 抽出完了: 誰ガ為のアルケミスト
# 抽出完了: デッキヒーローズ-本格派戦略カードゲーム-
# 抽出完了: 美少女戦士セーラームーン　セーラームーンドロップス
# 抽出完了: モンスターハンター エクスプロア
# 抽出完了: 夢色キャスト
# 抽出完了: グリムノーツ
# 抽出完了: DAME×PRINCE -ダメ王子たちとのドタバタ恋愛ADV
# 抽出完了: かんぱにガールズ ファンタジーRPG
# 抽出完了: デジモンリンクス
# 抽出完了: BFBチャンピオンズ2.0
# 抽出完了: フェアリーテイル 極・魔法乱舞
# 抽出完了: 12オーディンズ - 王道RPG
# 抽出完了: ラストピリオド - 終わりなき螺旋の物語 -
# 抽出完了: 聖闘士星矢 ゾディアック ブレイブ
# 抽出完了: ブレイブファンタジア【まったり＆簡単操作の爽快RPG】
# 抽出完了: 新発売　おそ松さんのへそくりウォーズ　〜ニートの攻防〜
# 抽出完了: 野球つく！！
# 抽出完了: VALKYRIE ANATOMIA(ヴァルキリーアナトミア)
# 抽出完了: ONE PIECE サウザンドストーム
# 抽出完了: 仮面ライダー バトルラッシュ
# 抽出完了: 実況パワフルサッカー 【選手育成サッカーゲーム】
# 抽出完了: スマッシュ＆マジック
# 抽出完了: オルタナティブガールズ
# 抽出完了: クックと魔法のレシピ おかわり（育成ゲーム）
# 抽出完了: セブンズストーリー
# 抽出完了: HIDE AND FIRE（ハイドアンドファイア）
# 抽出完了: 8 beat Story ~アイドル×音楽ゲーム~
# 抽出完了: テイルズ オブ ザ レイズ
# 抽出完了: NARUTO-ナルト- 疾風伝　ナルティメットブレイジング
# 抽出完了: ディシディアファイナルファンタジー オペラオムニア
# 抽出完了: ディズニー マイリトルドール
# 抽出完了: ハイキュー!!ドンピシャマッチ!!
# 抽出完了: ドールズオーダー 【チーム対戦アクション】
# 抽出完了: THE NEW GATE（ザ・ニュー・ゲート）
# 抽出完了: スーパー戦隊レジェンドウォーズ
# 抽出完了: 三国ブレイズ：オンライン三国志RPG
# 抽出完了: STAR OCEAN -anamnesis-
# 抽出完了: THE KING OF FIGHTERS ALLSTAR
# 抽出完了: ソードアート・オンライン メモリー・デフラグ
# 抽出完了: バンドやろうぜ！
# 抽出完了: 銀魂 かぶき町大活劇
# 抽出完了: ソウルリバース ゼロ（SOUL REVERSE ZERO）
# 抽出完了: モバサカ CHAMPIONS MANAGER
# 抽出完了: 恋愛幕末カレシ～恋愛ゲーム・乙女ゲーム女性向け～
# 抽出完了: 茜さすセカイでキミと詠う
# 抽出完了: キングダム セブンフラッグス
# 抽出完了: HIT - ヒット（本格アクションRPG）
# 抽出完了: 一血卍傑-ONLINE-
# 抽出完了: マギアレコード 魔法少女まどかマギカ外伝
# 抽出完了: ファンタジーライフ オンライン
# 抽出完了: マジカルデイズ｜魔法パズル×青春ストーリー！
# 抽出完了: 戦国幻武～本格軍勢バトル～
# 抽出完了: BRAVELY DEFAULT FAIRY'S EFFECT
# 抽出完了: 歌マクロス スマホDeカルチャー
# 抽出完了: にゅ～パズ松さん 新品卒業計画 【おそ松さんパズルゲーム】
# 抽出完了: ドラゴンクエストライバルズ エース
# 抽出完了: PaniPani -パラレルニクスパンドラナイト-
# 抽出完了: どうぶつの森 ポケットキャンプ
# 抽出完了: ららマジ
# 抽出完了: グラフィティスマッシュ
# 抽出完了: ジャンプチ ヒーローズ
# 抽出完了: StarHorsePocket+
# 抽出完了: トリカゴ スクラップマーチ
# 抽出完了: ジョジョの奇妙な冒険 ダイヤモンドレコーズ
# 抽出完了: うたのプリンスさまっ Shining Live
# 抽出完了: 千銃士
# 抽出完了: プリキュア つながるぱずるん
# 抽出完了: 幻想神域 -Link of Hearts-
# 抽出完了: 戦刻ナイトブラッド【戦国恋愛ファンタジーゲーム】
# 抽出完了: ファイトリーグ
# 抽出完了: ディズニー ツムツムランド
# 抽出完了: ［公式］進撃の巨人 チェインパズルフィーバー
# 抽出完了: プロジェクト東京ドールズ
# 抽出完了: 拡張少女系トライナリー
# 抽出完了: 僕のヒーローアカデミア スマッシュタップ
# 抽出完了: 東京喰種 ：re invoke
# 抽出完了: 結城友奈は勇者である 花結いのきらめき
# 抽出完了: デスティニーチャイルド
# 抽出完了: TRINITY MASTER - トリマス -
# 抽出完了: SINoALICE ーシノアリスー
# 抽出完了: AKB48ステージファイター2 バトルフェスティバル
# 抽出完了: 黒騎士と白の魔王
# 抽出完了: おそ松さん よくばり！ニートアイランド
# 抽出完了: 八月のシンデレラナイン
# 抽出完了: ミトラスフィア -MITRASPHERE-
# 抽出完了: ダンまち〜メモリア・フレーゼ〜
# 抽出完了: きららファンタジア
# 抽出完了: 週刊少年ジャンプ オレコレクション！
# 抽出完了: 欅のキセキ
# 抽出完了: エターナルリンケージ -蒼穹のアムネシア-
# 抽出完了: KING OF PRISM プリズムラッシュ！LIVE
# 抽出完了: サーヴァント オブ スローンズ
# 抽出完了: 恋愛プリンセス 恋愛ゲーム・乙女ゲーム女性向け
# 抽出完了: 機動戦士ガンダム 即応戦線
# 抽出完了: ワールド オブ ファイナルファンタジー メリメロ
# 抽出完了: ヴィーナスランブル
# 抽出完了: ぱすてるメモリーズ【ぱすメモ】～3DバトルRPG×美少女ゲー
# 抽出完了: 勇者のくせにこなまいきだDASH!
# 抽出完了: オーディナル ストラータ
# 抽出完了: Pancy(パンシー)-恋活・婚活マッチングアプリ
# 抽出完了: 仮面ライダー シティウォーズ
# 抽出完了: 幽遊白書 100%本気(マジ)バトル
# 抽出完了: ぷちぐるラブライブ！
# 抽出完了: 刀使ノ巫女 刻みし一閃の燈火
# 抽出完了: ドラゴン騎士団
# 抽出完了: 進撃の巨人 TACTICS
# 抽出完了: NARUTO X BORUTO 忍者BORUTAGE
# 抽出完了: ポポロクロイス物語 ～ナルシアの涙と妖精の笛
# 抽出完了: 三極ジャスティス
# 抽出完了: LINE：ディズニー トイカンパニー
# 抽出完了: アルテイルNEO
# 抽出完了: スヌーピー ライフ
# 抽出完了: レイヤードストーリーズ ゼロ
# 抽出完了: OVERHIT -オーバーヒット-
# 抽出完了: IS＜インフィニット・ストラトス＞アーキタイプ・ブレイカー
# 抽出完了: GOD EATER RESONANT OPS
# 抽出完了: 超進化物語
# 抽出完了: ワールドフリッパー(WORLD FLIPPER)
# 抽出完了: ハイスクール・フリート 艦隊バトルでピンチ！
# 抽出完了: AKB48ダイスキャラバン
# 抽出完了: KOFクロニクル
# 抽出完了: クロノマギア
# 抽出完了: モダンコンバット Versus
# 抽出完了: 宇宙戦艦ヤマト2202 -Hero's Record-
# 抽出完了: 23/7 トゥエンティ スリー セブン
# 抽出完了: バクレツモンスター
# 抽出完了: ときめきアイドル
# 抽出完了: 魔界ウォーズ
# 抽出完了: デジモンリアライズ
# 抽出完了: ドラガリアロスト
# 抽出完了: 明治東亰恋伽～ハヰカラデヱト～
# 抽出完了: のぶニャがの野望 ニャぷり！
# 抽出完了: 妖怪ウォッチ ワールド
# 抽出完了: 鬼灯の冷徹～地獄のパズルも君次第
# 抽出完了: LINE ブラウンストーリーズ
# 抽出完了: ワイルドアームズ ミリオンメモリーズ
# 抽出完了: ラブプラス EVERY
# 抽出完了: サファイア・スフィア〜蒼き境界〜
# 抽出完了: レジェンドオブリング
# 抽出完了: ラブライブ！スクールアイドルフェスティバルALL STARS
# 抽出完了: 戦国大河 - 天下統一シミュレーション
# 抽出完了: 爆走ドリフターズ
# 抽出完了: 【新作】フリージング エクステンション - 学園美少女RPG
# 抽出完了: 真・三國無双 斬
# 抽出完了: テラウォーズ
# 抽出完了: アークザラッド R
# 抽出完了: イドラ ファンタシースターサーガ
# 抽出完了: トロとパズル ~どこでもいっしょ~　（トロパズル）
# 抽出完了: オンエア！
# 抽出完了: リボルバーズエイト - リボハチ
# 抽出完了: ホップステップジャンパーズ
# 抽出完了: ワールドエンドヒーローズ
# 抽出完了: ArkResona -アークレゾナ-
# 抽出完了: シンエンレジスト
# 抽出完了: 転生したらスライムだった件 ～魔国連邦創世記～
# 抽出完了: ヴァンガード ZERO
# 抽出完了: 妖怪ウォッチ メダルウォーズ
# 抽出完了: ゲシュタルト・オーディン
# 抽出完了: 少女歌劇 レヴュースタァライト -Re LIVE-
# 抽出完了: 禍つヴァールハイト(まがつ)
# 抽出完了: 真・北斗無双
# 抽出完了: ブラッククローバー 夢幻の騎士団
# 抽出完了: 【新作】ユニティア（UNITIA）神託の使徒×終焉の女神
# 抽出完了: プレカトゥスの天秤
# 抽出完了: ツムツムスタジアム
# 抽出完了: ケンガン ULTIMATE BATTLE
# 抽出完了: リンクスリングス
# 抽出完了: ジョジョのピタパタポップ
# 抽出完了: ブレイドエクスロード
# 抽出完了: ゆる～いゲゲゲの鬼太郎 妖怪ドタバタ大戦争
# 抽出完了: 【劇プロ】劇的采配！プロ野球リバーサル
# 抽出完了: FAITH - フェイス
# 抽出完了: シティダンク
# 抽出完了: 〈物語〉シリーズ ぷくぷく
# 抽出完了: 【新作】Readyyy!
# 抽出完了: グリムエコーズ
# 抽出完了: DarkAvenger X - ダークアベンジャー クロス
# 抽出完了: ドラゴンネストM
# 抽出完了: 蒼天のスカイガレオン
# 抽出完了: 東京コンセプション
# 抽出完了: でみめん
# 抽出完了: ラストイデア
# 抽出完了: デビルブック
# 抽出完了: ディズニー ミュージックパレード
# 抽出完了: アイチュウ ÉtoileStage
# 抽出完了: この素晴らしい世界に祝福を！ファンタスティックデイズ
# 抽出完了: 重装出陣
# 抽出完了: 星鳴エコーズ
# 抽出完了: ドクターマリオ ワールド
# 抽出完了: ウルトラ怪獣バトルブリーダーズ
# 抽出完了: Witch's Weapon-魔女兵器-
# 抽出完了: なむあみだ仏っ！-蓮台 UTENA-
# 抽出完了: メリーガーランド　美少女 放置 RPG
# 抽出完了: HUNTER×HUNTER アリーナバトル
# 抽出完了: 最果てのバベル
# 抽出完了: LINE：ピクサー タワー ～おかいものパズル～
# 抽出完了: 暁のブレイカーズ  ～アクション・バトル～
# 抽出完了: 荒野のコトブキ飛行隊  大空のテイクオフガールズ！
# 抽出完了: ミイラの飼い方 パズルで育てる不思議な生き物-comico-
# 抽出完了: キックフライト
# 抽出完了: メガミラクルフォース(MEGAMIRACLE FORCE)
# 抽出完了: とある魔術の禁書目録 幻想収束
# 抽出完了: ラクガキキングダム -あなたの未来を描く育成RPG-
# 抽出完了: MARVEL Super War
# 抽出完了: 機動都市X：スーパーメカシティ
# 抽出完了: 乙女神楽 〜ザンビへの鎮魂歌〜
# 抽出完了: アカツキランド
# 抽出完了: 名探偵コナンランナー
# 抽出完了: ガンビット
# 抽出完了: テイルズ オブ クレストリア
# 抽出完了: 戦国BASARA バトルパーティー
# 抽出完了: 社長、バトルの時間です！
# 抽出完了: カラーピーソウト (COLOR PIECEOUT)
# 抽出完了: ゼノンザード(ZENONZARD)
# 抽出完了: ハリー・ポッター： 魔法同盟
# 抽出完了: ポケモンスクランブルSP
# 抽出完了: リーグ・オブ・ワンダーランド
# 抽出完了: revisions next stage
# 抽出完了: ユージェネ
# 抽出完了: 装甲娘
# 抽出完了: 快感フレーズ CLIMAX
# 抽出完了: 牧場婚活
# 抽出完了: Project NOAH - プロジェクト・ノア -
# 抽出完了: ガンダムブレイカーモバイル
# 抽出完了: 三国志大戦M：超本格戦略型カードRPG
# 抽出完了: 【MMORPG】TERA ORIGIN（テラオリジン）
# 抽出完了: カードキャプターさくら ハピネスメモリーズ
# 抽出完了: ドラゴン＆コロニーズ
# 抽出完了: MU：奇蹟の覚醒
# 抽出完了: ダンキラ!!! - Boys, be DANCING! -
# 抽出完了: プロ野球 ファミスタ マスターオーナーズ
# 抽出完了: ONE PIECE ボン！ボン！ジャーニー!!
# 抽出完了: HiGH＆LOW THE GAME
# 抽出完了: ロストディケイド
# 抽出完了: スヌーピー パズルジャーニー
# 抽出完了: ラピスリライツ 〜この世界のアイドルは魔法が使える〜
# 抽出完了: 聖闘士星矢 シャイニングソルジャーズ
# 抽出完了: 凍京NECRO SUICIDE MISSION
# 抽出完了: ブラックホライズン -Black Horizon-
# 抽出完了: Alice Closet
# 抽出完了: RANBU 三国志乱舞
# 抽出完了: THE KING OF FIGHTERS for GIRLS
# 抽出完了: CODE：SEED -星火ノ唄-
# 抽出完了: CUE! -See You Everyday-
# 抽出完了: Exos Heroes (エグゾス ヒーローズ)
# 抽出完了: LINE：ドラえもんパーク
# 抽出完了: かくりよの門-朧-
# 抽出完了: ソードアート・オンライン アリシゼーション・ブレイディング
# 抽出完了: 魔王と100人のお姫様
# 抽出完了: 三国志ヒーローズ
# 抽出完了: ロンドン迷宮譚 ： 本格ミステリー×アイテム探しゲーム
# 抽出完了: 東方キャノンボール
# 抽出完了: モンスターハンター ライダーズ
# 抽出完了: アークオーダー
# 抽出完了: ルミナスフォレスト〜選ばれし三人の勇者たち
# 抽出完了: アクション対魔忍
# 抽出完了: レッド：プライドオブエデン
# 抽出完了: 防振り ～らいんうぉーず！～
# 抽出完了: 蒼藍の誓い - ブルーオース
# 抽出完了: SHOW BY ROCK!! Fes A Live
# 抽出完了: ウインドボーイズ！
# 抽出完了: TRAHA
# 抽出完了: NARUTO X BORUTO 忍者TRIBES
# 抽出完了: 戦姫ストライク
# 抽出完了: アルゴナビス from BanG Dream! AAside
# 抽出完了: アニマル フロンティア
# 抽出完了: ユートピア・ゲート～双子の女神と未来へのつばさ～
# 抽出完了: ビッグバッドモンスターズ
# 抽出完了: 22/7 音楽の時間
# 抽出完了: マジカミ
# 抽出完了: エコーズ オブ パンドラ
# 抽出完了: 幻想神域2 -AURA KINGDOM-
# 抽出完了: ひぐらしのなく頃に 命
# 抽出完了: V4
# 抽出完了: 終末のアーカーシャ
# 抽出完了: アイコイノート
# 抽出完了: ステラクロニクル
# 抽出完了: NieR Re［in］carnation
# 抽出完了: Re：ゼロから始める異世界生活 リゼロス
# 抽出完了: アンノウンブライド
# 抽出完了: ガールズシンフォニー：Ec 〜新世界少女組曲〜
# 抽出完了: 食物語
# 抽出完了: メガミヒストリア
# 抽出完了: ルミア サガ-ちび萌え自由大冒険
# 抽出完了: ブラック・サージナイト
# 抽出完了: フィーバーダンク
# 抽出完了: HoneyWorks Premium Live（ハニプレ）
# 抽出完了: ガール・カフェ・ガン！
# 抽出完了: サクラ革命 ～華咲く乙女たち～
# 抽出完了: 金色のコルダ スターライトオーケストラ
# 抽出完了: グリザイア クロノスリベリオン
# 抽出完了: 夢境ワールド~元素使いの大冒険~
# 抽出完了: ワールドウィッチーズ UNITED FRONT（ユナフロ）
# 抽出完了: テラクラシック（TERA CLASSIC）
# 抽出完了: 咲う アルスノトリア
# 抽出完了: LINE 超大富豪
# 抽出完了: A.I.M.$ （エイムズ）
# 抽出完了: ロックマンX DiVE
# 抽出完了: スタースマッシュ
# 抽出完了: おねがい、俺を現実に戻さないで！ シンフォニアステージ
# 抽出完了: 乱闘三国志～放置群英伝～
# 抽出完了: 英雄*戦姫WW
# 抽出完了: ファンタジア・リビルド
# 抽出完了: アニマエ・アルケー
# 抽出完了: ブレイブ フロンティア レゾナ
# 抽出完了: ディープインサニティ アサイラム
# 抽出完了: FFVII THE FIRST SOLDIER
# 抽出完了: オルタンシア・サーガR
# 抽出完了: アイドルマスター ポップリンクス
# 抽出完了: BLUE REFLECTION SUN/燦
# 抽出完了: ドラゴンクエスト ダイの大冒険　-魂の絆-
# 抽出完了: ゲートオブナイトメア
# 抽出完了: 三国志群雄 本格三国RPG
# 抽出完了: Apex Legends Mobile
# 抽出完了: フィギュアストーリー
# 抽出完了: 蒼空ファンタジー
# 抽出完了: SHAMAN KING ふんばりクロニクル
# 抽出完了: BLAZBLUE ALTERNATIVE DARKWAR
# 抽出完了: ヴェルヴェットコード -Velvet Code-
# 抽出完了: コードギアス Genesic Re;CODE
# 抽出完了: 無職転生 ～ゲームになっても本気だす～
# 抽出完了: フットサルボーイズ!!!!! ハイファイリーグ
# 抽出完了: キングダムDASH!!
# 抽出完了: sin 七つの大罪 X-TASY
# 抽出完了: にょろっこ【非対称対戦サバイバルアクション】オンラインゲーム
# 抽出完了: 魔法科高校の劣等生 リローデッド・メモリ
# 抽出完了: デッドバイデイライト・モバイル - NetEase
# 抽出完了: シン・クロニクル
# 抽出完了: マナシスリフレイン
# 抽出完了: エクリプスサーガ
# 抽出完了: 月光彫刻師
# 抽出完了: 恋愛戦国ロマネスク 女性向け人気恋愛ゲーム
# 抽出完了: プラオレ！～SMILE PRINCESS～
# 抽出完了: テイルズウィーバー ： SecondRun
# 抽出完了: 彼女、お借りします ヒロインオールスターズ
# 抽出完了: アイドルマスター SideM GROWING STARS
# 抽出完了: シドニアの騎士 掌位ノ絆
# 抽出完了: D_CIDE TRAUMEREI ディーサイドトロイメライ
# 抽出完了: ドラゴンクエストけしケシ！
# 抽出完了: 遊戯王クロスデュエル
# 抽出完了: 聖剣伝説 ECHOES of MANA
# 抽出完了: ［AKB48公式］ AKB48 WORLD
# 抽出完了: 夢職人と忘れじの黒い妖精
# 抽出完了: アーテリーギア-機動戦姫-
# 抽出完了: EXtreme LIVES
# 抽出完了: EXTASY VISUAL SHOCK
# 抽出完了: テイルズ オブ ルミナリア
# 抽出完了: 機動戦士ガンダム 鉄血のオルフェンズG
# 抽出完了: ブレイブリーデフォルト ブリリアントライツ
# 抽出完了: メモリア  夢の旅人と双子の案内人
# 抽出完了: クローバーシアター
# 抽出完了: 404 GAME RE：SET -エラーゲームリセット-
# 抽出完了: ミラクルマッチ
# 抽出完了: 鋼の錬金術師 MOBILE
# 抽出完了: テクノロイド ユニゾンハート
# 抽出完了: エターナルツリー
# 抽出完了: からかい上手の高木さん キュンキュンレコーズ
# 抽出完了: エンゲージ・キル（Engage Kill）
# 抽出完了: ＆0
# 抽出完了: タワーオブスカイ
# 抽出完了: アストラル・ミラージュ -幻城の姫君-
# 抽出完了: 真・三國無双 M
# 抽出完了: クローズ×WORST - XROSS OVER -
# 抽出完了: アスタータタリクス
# 抽出完了: ＃コンパス ライブアリーナ
# 抽出完了: ミステリーレコード｜協力×謎解きの脱出アドベンチャーゲーム
# 抽出完了: ユアマジェスティ
# 抽出完了: ダチメン伝説G　転生ヤンキーギルドバトルRPG
# 抽出完了: アルゴナビス -キミが見たステージへ-
# 抽出完了: マブラヴ：ディメンションズ
# 抽出完了: ゴールドラッシュバトラー
# 抽出完了: BLACK STELLA PTOLOMEA
# 抽出完了: takt op. 運命は真紅き旋律の街を
# 抽出完了: ネバーアフター～逆転メルヘン～
# 抽出完了: ラブライブ！スクールアイドルフェスティバル2（スクフェス2）
# 抽出完了: トワツガイ
# 抽出完了: かみながしじま 〜輪廻の巫女〜
# 抽出完了: キュービックスターズ ギリギリ直感シューティングゲーム
# 抽出完了: 機兵とドラゴン
# 抽出完了: GGGGG　協力・対戦アクションゲーム
# 抽出完了: 太鼓の達人 RHYTHM CONNECT
# 抽出完了: 金色のガッシュベル！！ 永遠の絆の仲間たち
# 抽出完了: エレメンタルストーリーワールド
# 抽出完了: モルガナティック・アイドル 乙女ゲーム・恋愛ゲーム
# 抽出完了: 廻らぬ星のステラリウム
# 抽出完了: タップハンター～剣と魔法の放置RPG～
# 抽出完了: 青山オペレッタ

# %% [markdown]
# ### 年月列をクリーンアップしてからCSV保存

# %%
df = pd.DataFrame(results)

# 年月列のクリーンアップ処理
if "年月" in df.columns:
    df["年月"] = (
        df["年月"]
        .astype(str)
        .str.replace(r'^[=]*["]*', '', regex=True)  # 先頭の = や " を除去
        .str.replace(r'["]*$', '', regex=True)      # 末尾の " を除去
        .str.replace("/", "-")                      # スラッシュ → ハイフン
    )
df.to_csv("gamei_apps_sales_summary_utf8bom_ver2.csv", index=False, encoding="utf-8-sig")
